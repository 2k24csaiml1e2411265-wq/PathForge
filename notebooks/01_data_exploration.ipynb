# %% [markdown]
# # 01 — Data Exploration
# Explore the PathForge job dataset (`data/jobs.csv`) before running the rest of the pipeline.
#
# > This notebook uses the small **sample** dataset bundled with the project. See `data/ingest_real_dataset.py` to plug in a larger, real dataset later.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
import pandas as pd
from src.utils import load_jobs_dataframe

jobs_df = load_jobs_dataframe()
print(f'Loaded {len(jobs_df)} job postings')
jobs_df.head()
# Out:
# Loaded 80 job postings
#    job_id       job_title              company         location  \
# 0       1  Data Scientist  Corestack Solutions  Gurugram, India
# 1       2  Data Scientist     Nimbus Analytics      Pune, India
# 2       3  Data Scientist          Solstice AI     Noida, India
# 3       4  Data Scientist      Skyline Systems      Pune, India
# 4       5  Data Scientist     Vertex Data Labs     Noida, India
#
#                                          description  \
# 0  We are looking for a intern Data Scientist to ...
# 1  We are looking for a senior Data Scientist to ...
# 2  We are looking for a entry-level Data Scientis...
# 3  We are looking for a entry-level Data Scientis...
# 4  We are looking for a intern Data Scientist to ...
#
#                                               skills    seniority    industry
# 0  pandas; machine learning; scikit-learn; statis...       Intern  Technology
# ...

# %% [markdown]
# ## Basic shape and schema

# %%
jobs_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   job_id       80 non-null     int64
#  1   job_title    80 non-null     str
#  2   company      80 non-null     str
#  3   location     80 non-null     str
#  4   description  80 non-null     str
#  5   skills       80 non-null     str
#  6   seniority    80 non-null     str
#  7   industry     80 non-null     str
# dtypes: int64(1), str(7)
# memory usage: 39.7 KB

# %%
jobs_df.isna().sum()
# Out:
# job_id         0
# job_title      0
# company        0
# location       0
# description    0
# skills         0
# seniority      0
# industry       0
# dtype: int64

# %% [markdown]
# ## Postings per role

# %%
jobs_df['job_title'].value_counts()
# Out:
# job_title
# Data Scientist               8
# Machine Learning Engineer    8
# NLP Engineer                 8
# Data Analyst                 8
# Backend Developer            8
# Full Stack Developer         8
# Cloud/DevOps Engineer        8
# AI Product Manager           8
# Computer Vision Engineer     8
# Database Administrator       8
# Name: count, dtype: int64

# %% [markdown]
# ## Postings per seniority level

# %%
jobs_df['seniority'].value_counts()
# Out:
# seniority
# Mid-level      26
# Entry-level    23
# Intern         17
# Senior         14
# Name: count, dtype: int64

# %% [markdown]
# ## Postings per industry

# %%
jobs_df['industry'].value_counts()
# Out:
# industry
# Technology    23
# Finance       16
# Healthcare     9
# E-commerce     8
# Retail         5
# Startups       5
# Automotive     4
# Telecom        4
# Media          3
# Consulting     3
# Name: count, dtype: int64

# %% [markdown]
# ## Sample job description

# %%
print(jobs_df.iloc[0]['description'])
print('\nRequired skills:', jobs_df.iloc[0]['skills'])
# Out:
# We are looking for a intern Data Scientist to join our technology team. The ideal candidate has hands-on experience with pandas, machine learning, scikit-learn, statistics, sql, python. You will work on real-world problems, collaborate with cross-functional teams, and help ship production-quality solutions.
#
# Required skills: pandas; machine learning; scikit-learn; statistics; sql; python
